# %% [markdown]
# # Практическая работа №8

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Задание 1

# %%
import pandas as pd

data = pd.DataFrame(
    data={
        'Улица': [80, 98, 75, 91, 78],
        'Гараж': [100, 82, 105, 89, 102],
    },
    index=['Понедельник', 'Вторник', 'Среда', 'Четверг', 'Пятница']
)

data
# Out:
#              Улица  Гараж
# Понедельник     80    100
# Вторник         98     82
# Среда           75    105
# Четверг         91     89
# Пятница         78    102

# %%
print(
    f"Коэффициент корреляции:",
    f"{data['Улица'].corr(data['Гараж'])}"
)
# Out:
# Коэффициент корреляции: -0.9999999999999998

# %% [markdown]
# # Задание 2

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
data_fig = plt.figure()

plt.grid(True)
plt.title('Диаграмма рассеяния', fontsize=20)
plt.xlabel('Число автомобилей на уличной стоянке', fontsize=12)
plt.ylabel('Число автомобилей в подземном гараже', fontsize=12)

plt.scatter(x=data['Улица'], y=data['Гараж'])
plt.show()
# Out:
# <div id='9cccf9af-5cf4-424f-9b99-dc31b05b0544'></div>

# %% [markdown]
# # Задание 3

# %%
bitcoin = pd.read_csv('bitcoin.csv')
bitcoin.drop(['Unnamed: 0'], axis=1, inplace=True)

print(f'Dataframe dimensions: {bitcoin.shape}')
bitcoin.head()
# Out:
# Dataframe dimensions: (2001, 7)
#          time    high     low    open  volumefrom     volumeto   close
# 0  2015-12-20  462.76  431.10  461.20   121531.64  54316484.95  441.78
# 1  2015-12-21  445.54  423.99  441.78   121990.88  53270215.60  437.59
# 2  2015-12-22  443.22  433.25  437.59    65785.54  28845536.39  437.03
# 3  2015-12-23  444.78  434.28  437.03    63247.04  27877349.10  442.43
# 4  2015-12-24  460.62  441.76  442.43    79604.01  36096662.15  452.98

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        2001 non-null   object
#  1   high        2001 non-null   float64
#  2   low         2001 non-null   float64
#  3   open        2001 non-null   float64
#  4   volumefrom  2001 non-null   float64
#  5   volumeto    2001 non-null   float64
#  6   close       2001 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 109.6+ KB

# %% [markdown]
# # Задание 4

# %%
import numpy as np

date_to_cost = pd.DataFrame(
    data={
        'time': pd.to_datetime(bitcoin['time']),
        'predict': bitcoin['close'].shift(-14), # [:-14]
    },
)

date_to_cost.tail(20)
# Out:
#            time   predict
# 1981 2021-05-23  35798.57
# 1982 2021-05-24  33582.86
# 1983 2021-05-25  33409.38
# 1984 2021-05-26  37391.58
# 1985 2021-05-27  36680.78
# 1986 2021-05-28  36843.33
# 1987 2021-05-29       NaN
# 1988 2021-05-30       NaN
# 1989 2021-05-31       NaN
# 1990 2021-06-01       NaN
# 1991 2021-06-02       NaN
# 1992 2021-06-03       NaN
# 1993 2021-06-04       NaN
# 1994 2021-06-05       NaN
# 1995 2021-06-06       NaN
# 1996 2021-06-07       NaN
# 1997 2021-06-08       NaN
# 1998 2021-06-09       NaN
# 1999 2021-06-10       NaN
# 2000 2021-06-11       NaN

# %%
date_to_cost['time'] = (date_to_cost['time'] - date_to_cost['time'].min()) / np.timedelta64(1, 'D')

date_to_cost.tail(20)
# Out:
#         time   predict
# 1981  1981.0  35798.57
# 1982  1982.0  33582.86
# 1983  1983.0  33409.38
# 1984  1984.0  37391.58
# 1985  1985.0  36680.78
# 1986  1986.0  36843.33
# 1987  1987.0       NaN
# 1988  1988.0       NaN
# 1989  1989.0       NaN
# 1990  1990.0       NaN
# 1991  1991.0       NaN
# 1992  1992.0       NaN
# 1993  1993.0       NaN
# 1994  1994.0       NaN
# 1995  1995.0       NaN
# 1996  1996.0       NaN
# 1997  1997.0       NaN
# 1998  1998.0       NaN
# 1999  1999.0       NaN
# 2000  2000.0       NaN

# %%
date_to_cost.dtypes
# Out:
# time       float64
# predict    float64
# dtype: object

# %%
date_to_cost.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4e90e_row0_col0, #T_4e90e_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4e90e_row0_col1, #T_4e90e_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e90e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e90e_level0_col0" class="col_heading level0 col0" >time</th>
#       <th id="T_4e90e_level0_col1" class="col_heading level0 col1" >predict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e90e_level0_row0" class="row_heading level0 row0" >time</th>
#       <td id="T_4e90e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4e90e_row0_col1" class="data row0 col1" >0.678006</td>
#     </tr>
#     <tr>
#       <th id="T_4e90e_level0_row1" class="row_heading level0 row1" >predict</th>
#       <td id="T_4e90e_row1_col0" class="data row1 col0" >0.678006</td>
#       <td id="T_4e90e_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Задание 5

# %%
from sklearn.linear_model import LinearRegression

X = np.array(date_to_cost['time']).reshape(-1, 1)
y = np.array(date_to_cost['predict'])

regression_btc = LinearRegression().fit(X[:-14], y[:-14])

# %%
prediction_btc = regression_btc.predict(X).flatten()
prediction_btc
# Out:
# array([-5095.21928157, -5080.55751728, -5065.89575299, ...,
#        24198.98576758, 24213.64753187, 24228.30929616])

# %%
prediction_btc = pd.DataFrame(
    data={
        'Предсказанная (от даты) стоимость Bitcoin, $': prediction_btc[-14:],
        'Реально зафиксированная стоимость Bitcoin, $': bitcoin['close'][-14:],
    },
)
prediction_btc.index = bitcoin['time'][-14:]
prediction_btc.index.names = ['Дата']

prediction_btc
# Out:
#             Предсказанная (от даты) стоимость Bitcoin, $  \
# Дата
# 2021-05-29                                  24037.706360
# 2021-05-30                                  24052.368125
# 2021-05-31                                  24067.029889
# 2021-06-01                                  24081.691653
# 2021-06-02                                  24096.353418
# 2021-06-03                                  24111.015182
# 2021-06-04                                  24125.676946
# 2021-06-05                                  24140.338710
# 2021-06-06                                  24155.000475
# 2021-06-07                                  24169.662239
# 2021-06-08                                  24184.324003
# 2021-06-09                                  24198.985768
# 2021-06-10                                  24213.647532
# 2021-06-11                                  24228.309296
#
#             Реально зафиксированная стоимость Bitcoin, $
# Дата
# 2021-05-29                                      34611.58
# 2021-05-30                                      35662.59
# 2021-05-31                                      37290.83
# 2021-06-01                                      36683.51
# 2021-06-02                                      37576.98
# 2021-06-03                                      39229.66
# 2021-06-04                                      36861.50
# 2021-06-05                                      35538.40
# 2021-06-06                                      35798.57
# 2021-06-07                                      33582.86
# 2021-06-08                                      33409.38
# 2021-06-09                                      37391.58
# 2021-06-10                                      36680.78
# 2021-06-11                                      36843.33

# %% [markdown]
# # Задание 6

# %%
print(
    f"Наклон линии регрессии: {regression_btc.coef_[0]}",
    f"Y-перехват: {regression_btc.intercept_}",
sep='\n')
# Out:
# Наклон линии регрессии: 14.661764288867017
# Y-перехват: -5095.219281572679

# %% [markdown]
# # Задание 7

# %%
bitcoin_fig, ax = plt.subplots(figsize=(12.8, 12))
bitcoin_fig.subplots_adjust(0.075, 0.075, 0.975, 0.95)

plt.title('Зависимость между датой и стоимостью Bitcoin', fontsize=20)

plt.scatter(
    x=date_to_cost['time'], y=date_to_cost['predict'],
    alpha=0.5, label='Диаграмма рассеяния',
)
plt.plot(
    X, regression_btc.predict(X),
    color='crimson', linewidth=3,
    label='Простая линейная регрессия',
)

plt.xlabel('Дата в формате "год-месяц-день"', fontsize=14)
plt.xticks(ticks=date_to_cost['time'][::500], labels=bitcoin['time'][::500])
plt.ylabel('Стоимость Bitcoin, $', fontsize=14)

plt.grid(True)
plt.legend(loc='upper left')
plt.show()
# Out:
# <div id='b24bfe3c-e5a3-47dd-8bc7-bf58fc074eb8'></div>

# %% [markdown]
# # Задание 8

# %%
price = pd.read_csv('housePrice.csv', thousands=',')

print(f'Dataframe dimensions: {price.shape}')
price.head()
# Out:
# Dataframe dimensions: (3479, 8)
#    Area  Room  Parking  Warehouse  Elevator         Address         Price  \
# 0    63     1     True       True      True         Shahran  1.850000e+09
# 1    60     1     True       True      True         Shahran  1.850000e+09
# 2    79     2     True       True      True          Pardis  5.500000e+08
# 3    95     2     True       True      True   Shahrake Qods  9.025000e+08
# 4   123     2     True       True      True  Shahrake Gharb  7.000000e+09
#
#    Price(USD)
# 0    61666.67
# 1    61666.67
# 2    18333.33
# 3    30083.33
# 4   233333.33

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   int64
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(2), int64(2), object(1)
# memory usage: 146.2+ KB

# %%
price.describe()
# Out:
#                Area         Room         Price    Price(USD)
# count  3.479000e+03  3479.000000  3.479000e+03  3.479000e+03
# mean   8.744000e+06     2.079908  5.359023e+09  1.786341e+05
# std    3.167266e+08     0.758275  8.099935e+09  2.699978e+05
# min    3.000000e+01     0.000000  3.600000e+06  1.200000e+02
# 25%    6.900000e+01     2.000000  1.418250e+09  4.727500e+04
# 50%    9.000000e+01     2.000000  2.900000e+09  9.666667e+04
# 75%    1.200000e+02     2.000000  6.000000e+09  2.000000e+05
# max    1.616000e+10     5.000000  9.240000e+10  3.080000e+06

# %% [markdown]
# # Задание 9

# %%
quantile = price['Area'].quantile(.99)

price = price[price['Area'] < quantile]

# %%
price.describe()
# Out:
#               Area         Room         Price    Price(USD)
# count  3444.000000  3444.000000  3.444000e+03  3.444000e+03
# mean    102.653020     2.068525  5.124715e+09  1.708238e+05
# std      51.376075     0.740871  7.100481e+09  2.366827e+05
# min      30.000000     0.000000  3.600000e+06  1.200000e+02
# 25%      68.000000     2.000000  1.400000e+09  4.666667e+04
# 50%      90.000000     2.000000  2.850000e+09  9.500000e+04
# 75%     120.000000     2.000000  6.000000e+09  2.000000e+05
# max     405.000000     5.000000  8.500000e+10  2.833333e+06

# %%
price.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_73129_row0_col0, #T_73129_row1_col1, #T_73129_row2_col2, #T_73129_row3_col3, #T_73129_row4_col4, #T_73129_row5_col5, #T_73129_row5_col6, #T_73129_row6_col5, #T_73129_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_73129_row0_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_73129_row0_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_73129_row0_col3, #T_73129_row3_col0, #T_73129_row3_col1, #T_73129_row3_col5, #T_73129_row3_col6, #T_73129_row5_col2, #T_73129_row5_col4, #T_73129_row6_col2, #T_73129_row6_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_73129_row0_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_73129_row0_col5, #T_73129_row0_col6 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_73129_row1_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_73129_row1_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_73129_row1_col3, #T_73129_row5_col3, #T_73129_row6_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_73129_row1_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_73129_row1_col5, #T_73129_row1_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_73129_row2_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_73129_row2_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_73129_row2_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_73129_row2_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_73129_row2_col5, #T_73129_row2_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_73129_row3_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_73129_row3_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_73129_row4_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_73129_row4_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_73129_row4_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_73129_row4_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_73129_row4_col5, #T_73129_row4_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_73129_row5_col0, #T_73129_row6_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_73129_row5_col1, #T_73129_row6_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# </style>
# <table id="T_73129">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73129_level0_col0" class="col_heading level0 col0" >Area</th>
#       <th id="T_73129_level0_col1" class="col_heading level0 col1" >Room</th>
#       <th id="T_73129_level0_col2" class="col_heading level0 col2" >Parking</th>
#       <th id="T_73129_level0_col3" class="col_heading level0 col3" >Warehouse</th>
#       <th id="T_73129_level0_col4" class="col_heading level0 col4" >Elevator</th>
#       <th id="T_73129_level0_col5" class="col_heading level0 col5" >Price</th>
#       <th id="T_73129_level0_col6" class="col_heading level0 col6" >Price(USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73129_level0_row0" class="row_heading level0 row0" >Area</th>
#       <td id="T_73129_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_73129_row0_col1" class="data row0 col1" >0.788524</td>
#       <td id="T_73129_row0_col2" class="data row0 col2" >0.256229</td>
#       <td id="T_73129_row0_col3" class="data row0 col3" >0.122530</td>
#       <td id="T_73129_row0_col4" class="data row0 col4" >0.182814</td>
#       <td id="T_73129_row0_col5" class="data row0 col5" >0.797784</td>
#       <td id="T_73129_row0_col6" class="data row0 col6" >0.797784</td>
#     </tr>
#     <tr>
#       <th id="T_73129_level0_row1" class="row_heading level0 row1" >Room</th>
#       <td id="T_73129_row1_col0" class="data row1 col0" >0.788524</td>
#       <td id="T_73129_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_73129_row1_col2" class="data row1 col2" >0.274778</td>
#       <td id="T_73129_row1_col3" class="data row1 col3" >0.128165</td>
#       <td id="T_73129_row1_col4" class="data row1 col4" >0.207735</td>
#       <td id="T_73129_row1_col5" class="data row1 col5" >0.570775</td>
#       <td id="T_73129_row1_col6" class="data row1 col6" >0.570775</td>
#     </tr>
#     <tr>
#       <th id="T_73129_level0_row2" class="row_heading level0 row2" >Parking</th>
#       <td id="T_73129_row2_col0" class="data row2 col0" >0.256229</td>
#       <td id="T_73129_row2_col1" class="data row2 col1" >0.274778</td>
#       <td id="T_73129_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_73129_row2_col3" class="data row2 col3" >0.428808</td>
#       <td id="T_73129_row2_col4" class="data row2 col4" >0.437644</td>
#       <td id="T_73129_row2_col5" class="data row2 col5" >0.213059</td>
#       <td id="T_73129_row2_col6" class="data row2 col6" >0.213059</td>
#     </tr>
#     <tr>
#       <th id="T_73129_level0_row3" class="row_heading level0 row3" >Warehouse</th>
#       <td id="T_73129_row3_col0" class="data row3 col0" >0.122530</td>
#       <td id="T_73129_row3_col1" class="data row3 col1" >0.128165</td>
#       <td id="T_73129_row3_col2" class="data row3 col2" >0.428808</td>
#       <td id="T_73129_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_73129_row3_col4" class="data row3 col4" >0.199383</td>
#       <td id="T_73129_row3_col5" class="data row3 col5" >0.126712</td>
#       <td id="T_73129_row3_col6" class="data row3 col6" >0.126712</td>
#     </tr>
#     <tr>
#       <th id="T_73129_level0_row4" class="row_heading level0 row4" >Elevator</th>
#       <td id="T_73129_row4_col0" class="data row4 col0" >0.182814</td>
#       <td id="T_73129_row4_col1" class="data row4 col1" >0.207735</td>
#       <td id="T_73129_row4_col2" class="data row4 col2" >0.437644</td>
#       <td id="T_73129_row4_col3" class="data row4 col3" >0.199383</td>
#       <td id="T_73129_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_73129_row4_col5" class="data row4 col5" >0.162221</td>
#       <td id="T_73129_row4_col6" class="data row4 col6" >0.162221</td>
#     </tr>
#     <tr>
#       <th id="T_73129_level0_row5" class="row_heading level0 row5" >Price</th>
#       <td id="T_73129_row5_col0" class="data row5 col0" >0.797784</td>
#       <td id="T_73129_row5_col1" class="data row5 col1" >0.570775</td>
#       <td id="T_73129_row5_col2" class="data row5 col2" >0.213059</td>
#       <td id="T_73129_row5_col3" class="data row5 col3" >0.126712</td>
#       <td id="T_73129_row5_col4" class="data row5 col4" >0.162221</td>
#       <td id="T_73129_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_73129_row5_col6" class="data row5 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73129_level0_row6" class="row_heading level0 row6" >Price(USD)</th>
#       <td id="T_73129_row6_col0" class="data row6 col0" >0.797784</td>
#       <td id="T_73129_row6_col1" class="data row6 col1" >0.570775</td>
#       <td id="T_73129_row6_col2" class="data row6 col2" >0.213059</td>
#       <td id="T_73129_row6_col3" class="data row6 col3" >0.126712</td>
#       <td id="T_73129_row6_col4" class="data row6 col4" >0.162221</td>
#       <td id="T_73129_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_73129_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
price.drop(['Price'], axis=1, inplace=True)

price.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_43ac6_row0_col0, #T_43ac6_row1_col1, #T_43ac6_row2_col2, #T_43ac6_row3_col3, #T_43ac6_row4_col4, #T_43ac6_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_43ac6_row0_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_43ac6_row0_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_43ac6_row0_col3, #T_43ac6_row3_col0, #T_43ac6_row3_col1, #T_43ac6_row3_col5, #T_43ac6_row5_col2, #T_43ac6_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_43ac6_row0_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_43ac6_row0_col5 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_43ac6_row1_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_43ac6_row1_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_43ac6_row1_col3, #T_43ac6_row5_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_43ac6_row1_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_43ac6_row1_col5 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_43ac6_row2_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_43ac6_row2_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_43ac6_row2_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_43ac6_row2_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_43ac6_row2_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_43ac6_row3_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_43ac6_row3_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_43ac6_row4_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_43ac6_row4_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_43ac6_row4_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_43ac6_row4_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_43ac6_row4_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_43ac6_row5_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_43ac6_row5_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# </style>
# <table id="T_43ac6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43ac6_level0_col0" class="col_heading level0 col0" >Area</th>
#       <th id="T_43ac6_level0_col1" class="col_heading level0 col1" >Room</th>
#       <th id="T_43ac6_level0_col2" class="col_heading level0 col2" >Parking</th>
#       <th id="T_43ac6_level0_col3" class="col_heading level0 col3" >Warehouse</th>
#       <th id="T_43ac6_level0_col4" class="col_heading level0 col4" >Elevator</th>
#       <th id="T_43ac6_level0_col5" class="col_heading level0 col5" >Price(USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43ac6_level0_row0" class="row_heading level0 row0" >Area</th>
#       <td id="T_43ac6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_43ac6_row0_col1" class="data row0 col1" >0.788524</td>
#       <td id="T_43ac6_row0_col2" class="data row0 col2" >0.256229</td>
#       <td id="T_43ac6_row0_col3" class="data row0 col3" >0.122530</td>
#       <td id="T_43ac6_row0_col4" class="data row0 col4" >0.182814</td>
#       <td id="T_43ac6_row0_col5" class="data row0 col5" >0.797784</td>
#     </tr>
#     <tr>
#       <th id="T_43ac6_level0_row1" class="row_heading level0 row1" >Room</th>
#       <td id="T_43ac6_row1_col0" class="data row1 col0" >0.788524</td>
#       <td id="T_43ac6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_43ac6_row1_col2" class="data row1 col2" >0.274778</td>
#       <td id="T_43ac6_row1_col3" class="data row1 col3" >0.128165</td>
#       <td id="T_43ac6_row1_col4" class="data row1 col4" >0.207735</td>
#       <td id="T_43ac6_row1_col5" class="data row1 col5" >0.570775</td>
#     </tr>
#     <tr>
#       <th id="T_43ac6_level0_row2" class="row_heading level0 row2" >Parking</th>
#       <td id="T_43ac6_row2_col0" class="data row2 col0" >0.256229</td>
#       <td id="T_43ac6_row2_col1" class="data row2 col1" >0.274778</td>
#       <td id="T_43ac6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_43ac6_row2_col3" class="data row2 col3" >0.428808</td>
#       <td id="T_43ac6_row2_col4" class="data row2 col4" >0.437644</td>
#       <td id="T_43ac6_row2_col5" class="data row2 col5" >0.213059</td>
#     </tr>
#     <tr>
#       <th id="T_43ac6_level0_row3" class="row_heading level0 row3" >Warehouse</th>
#       <td id="T_43ac6_row3_col0" class="data row3 col0" >0.122530</td>
#       <td id="T_43ac6_row3_col1" class="data row3 col1" >0.128165</td>
#       <td id="T_43ac6_row3_col2" class="data row3 col2" >0.428808</td>
#       <td id="T_43ac6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_43ac6_row3_col4" class="data row3 col4" >0.199383</td>
#       <td id="T_43ac6_row3_col5" class="data row3 col5" >0.126712</td>
#     </tr>
#     <tr>
#       <th id="T_43ac6_level0_row4" class="row_heading level0 row4" >Elevator</th>
#       <td id="T_43ac6_row4_col0" class="data row4 col0" >0.182814</td>
#       <td id="T_43ac6_row4_col1" class="data row4 col1" >0.207735</td>
#       <td id="T_43ac6_row4_col2" class="data row4 col2" >0.437644</td>
#       <td id="T_43ac6_row4_col3" class="data row4 col3" >0.199383</td>
#       <td id="T_43ac6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_43ac6_row4_col5" class="data row4 col5" >0.162221</td>
#     </tr>
#     <tr>
#       <th id="T_43ac6_level0_row5" class="row_heading level0 row5" >Price(USD)</th>
#       <td id="T_43ac6_row5_col0" class="data row5 col0" >0.797784</td>
#       <td id="T_43ac6_row5_col1" class="data row5 col1" >0.570775</td>
#       <td id="T_43ac6_row5_col2" class="data row5 col2" >0.213059</td>
#       <td id="T_43ac6_row5_col3" class="data row5 col3" >0.126712</td>
#       <td id="T_43ac6_row5_col4" class="data row5 col4" >0.162221</td>
#       <td id="T_43ac6_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Задание 10

# %%
X, y = price['Area'], price['Price(USD)']

n = np.size(X)
m_X, m_y = np.mean(X), np.mean(y)

SS_Xy = np.sum(y*X) - n * (m_y * m_X)
SS_XX = np.sum(X*X) - n * (m_X * m_X)

# %% [markdown]
# # Задание 11

# %%
coef_price = SS_Xy / SS_XX
intercept_price = m_y - (coef_price * m_X)

print(
    f"Наклон линии регрессии: {coef_price}",
    f"Y-перехват: {intercept_price}",
sep='\n')
# Out:
# Наклон линии регрессии: 3675.282602461848
# Y-перехват: -206455.00915985904

# %%
np_X = np.array(X).reshape(-1, 1)

regression_price = LinearRegression().fit(np_X, y)
prediction_price = regression_price.predict(np_X).flatten()

print(
    f"Наклон линии регрессии: {regression_price.coef_[0]}",
    f"Y-перехват: {regression_price.intercept_}",
sep='\n')
# Out:
# Наклон линии регрессии: 3675.2826024618457
# Y-перехват: -206455.0091598588

# %% [markdown]
# # Задание 12

# %%
price_fig, bx = plt.subplots(figsize=(12.8, 12))
price_fig.subplots_adjust(0.075, 0.075, 0.975, 0.95)

plt.title('Зависимость между площадью и стоимостью дома', fontsize=20)

plt.scatter(
    x=X, y=y,
    alpha=0.5, label='Диаграмма рассеяния',
)
plt.plot(
    X, intercept_price + (coef_price * X),
    color='crimson', linewidth=3,
    label='Простая линейная регрессия',
)

plt.xlabel('Площадь дома', fontsize=14)
plt.ylabel('Стоимость дома, $', fontsize=14)

plt.grid(True)
plt.legend(loc='upper left')
plt.show()
# Out:
# <div id='d7097a13-6d21-4244-81c6-ac61eac8c66d'></div>
